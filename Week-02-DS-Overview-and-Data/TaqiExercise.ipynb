# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
data_size= df_food.shape
print(data_size)
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
print (df_food.dtypes) 
#print (df_food.columns)
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_dropped= df_food[['calories_day', 'weight', 'Gender']]

df_dropped.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
#df_dropped.isnull()
df_dropped.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_dropped= df_dropped.dropna()
df_dropped.head()
# Out:
#    calories_day                    weight  Gender
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1
# 5           3.0                       190       1

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
#df_dropped.head()
df_dropped['weight']=pd.to_numeric(df_dropped['weight'],errors='coerce')
df_dropped.head()
#df_dropped['weight'].dropna()

df_dropped= df_dropped.dropna()
df_dropped.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
#df.to_csv('path/to/your/file.csv', index=False)
df_dropped.to_csv('data/cleandedFile.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
sheet_id="1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw"
df_salary=pd.read_csv(f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv')
df_salary.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                             55,000
# 1                                             54,600
# 2                                             34,000
# 3                                             62,000
# 4                                             60,000
#
#    How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                0.0
# 1                                             4000.0
# 2                                                NaN
# 3                                             3000.0
# 4                                             7000.0
#
#   Please indicate the currency  \
# 0                          USD
# 1                          GBP
# 2                          USD
# 3                          USD
# 4                          USD
#
#   If "Other," please indicate the currency here:   \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   If your income needs additional context, please provide it here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What country do you work in?  \
# 0                United States
# 1               United Kingdom
# 2                           US
# 3                          USA
# 4                           US
#
#   If you're in the U.S., what state do you work in? What city do you work in?  \
# 0                                     Massachusetts                    Boston
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
#
#   How many years of professional work experience do you have overall?  \
# 0                                          5-7 years
# 1                                       8 - 10 years
# 2                                        2 - 4 years
# 3                                       8 - 10 years
# 4                                       8 - 10 years
#
#   How many years of professional work experience do you have in your field?  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
#
#   What is your highest level of education completed? What is your gender?  \
# 0                                    Master's degree                Woman
# 1                                     College degree           Non-binary
# 2                                     College degree                Woman
# 3                                     College degree                Woman
# 4                                     College degree                Woman
#
#   What is your race? (Choose all that apply.)
# 0                                       White
# 1                                       White
# 2                                       White
# 3                                       White
# 4                                       White

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
import os
original_filename = 'Ask A Manager Salary Survey 2021 (Responses).csv'
df_salary.to_csv(original_filename, index=False)

# Define the new filename
new_filename = 'salary_survey.csv'


# Rename the file
os.rename(original_filename, new_filename)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
print (df_salary.dtypes)

print (df_salary.columns)
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# If your job title needs additional context, please clarify here:                                                                                                                                                                         object
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)     object
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          float64
# Please indicate the currency                                                                                                                                                                                                             object
# If "Other," please indicate the currency here:                                                                                                                                                                                           object
# If your income needs additional context, please provide it here:                                                                                                                                                                         object
# What country do you work in?                                                                                                                                                                                                             object
# If you're in the U.S., what state do you work in?                                                                                                                                                                                        object
# What city do you work in?                                                                                                                                                                                                                object
# How many years of professional work experience do you have overall?                                                                                                                                                                      object
# How many years of professional work experience do you have in your field?                                                                                                                                                                object
# What is your highest level of education completed?                                                                                                                                                                                       object
# What is your gender?                                                                                                                                                                                                                     object
# What is your race? (Choose all that apply.)                                                                                                                                                                                              object
# dtype: object
# Index(['Timestamp', 'How old are you?', 'What industry do you work in?',
#        'Job title',
#        'If your job title needs additional context, please clarify here:',
#        'What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)',
#        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#        'Please indicate the currency',
#        'If "Other," please indicate the currency here: ',
#        'If your income needs additional context, please provide it here:',
#        'What country do you work in?',
#        'If you're in the U.S., what state do you work in?',
#        'What city do you work in?',
#        'How many years of professional work experience do you have overall?',
#        'How many years of professional work experience do you have in your field?',
#        'What is your highest level of education completed?',
#        'What is your gender?', 'What is your race? (Choose all that apply.)'],
#       dtype='object')

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed',	'gender', 'race']

df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# 2                      NaN      USD            NaN            NaN
# 3                   3000.0      USD            NaN            NaN
# 4                   7000.0      USD            NaN            NaN
#
#           country           state         city     total_yoe    field_yoe  \
# 0   United States   Massachusetts       Boston     5-7 years    5-7 years
# 1  United Kingdom             NaN    Cambridge  8 - 10 years    5-7 years
# 2              US       Tennessee  Chattanooga   2 - 4 years  2 - 4 years
# 3             USA       Wisconsin    Milwaukee  8 - 10 years    5-7 years
# 4              US  South Carolina   Greenville  8 - 10 years    5-7 years
#
#   highest_education_completed      gender   race
# 0             Master's degree       Woman  White
# 1              College degree  Non-binary  White
# 2              College degree       Woman  White
# 3              College degree       Woman  White
# 4              College degree       Woman  White

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
industry_size=df_salary['industry'].value_counts()

print(industry_size)
# Out:
# industry
# Computing or Tech                          4702
# Education (Higher Education)               2466
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1890
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

top_five_industry=industry_size.head(5).index



df_salary_tech= df_salary[df_salary['industry'].isin(top_five_industry)]

df_salary_tech.head()
# Out:
#             timestamp    age                      industry  \
# 0  4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34             Computing or Tech
# 3  4/27/2021 11:02:41  25-34                    Nonprofits
# 5  4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8  4/27/2021 11:03:01  45-54             Computing or Tech
#
#                                       title                 title_context  \
# 0        Research and Instruction Librarian                           NaN
# 1  Change & Internal Communications Manager                           NaN
# 3                           Program Manager                           NaN
# 5            Scholarly Publishing Librarian                           NaN
# 8                           Systems Analyst  Data developer/ETL Developer
#
#     salary  additional_compensation currency other_currency salary_context  \
# 0   55,000                      0.0      USD            NaN            NaN
# 1   54,600                   4000.0      GBP            NaN            NaN
# 3   62,000                   3000.0      USD            NaN            NaN
# 5   62,000                      NaN      USD            NaN            NaN
# 8  112,000                  10000.0      USD            NaN            NaN
#
#           country          state       city      total_yoe      field_yoe  \
# 0   United States  Massachusetts     Boston      5-7 years      5-7 years
# 1  United Kingdom            NaN  Cambridge   8 - 10 years      5-7 years
# 3             USA      Wisconsin  Milwaukee   8 - 10 years      5-7 years
# 5             USA  New Hampshire    Hanover   8 - 10 years    2 - 4 years
# 8              US       Missouri  St. Louis  21 - 30 years  21 - 30 years
#
#   highest_education_completed      gender   race
# 0             Master's degree       Woman  White
# 1              College degree  Non-binary  White
# 3              College degree       Woman  White
# 5             Master's degree         Man  White
# 8              College degree       Woman  White

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
sanity_check= ~ df_salary_tech['industry'].isin(top_five_industry)
sanity_check.head()
# Out:
# 0    False
# 1    False
# 3    False
# 5    False
# 8    False
# Name: industry, dtype: bool

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
usd=df_salary[ df_salary['currency'].isin(['USD']) ]

usd.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5  4/27/2021 11:02:46  25-34   Education (Higher Education)
#
#                                 title title_context  salary  \
# 0  Research and Instruction Librarian           NaN  55,000
# 2                Marketing Specialist           NaN  34,000
# 3                     Program Manager           NaN  62,000
# 4                  Accounting Manager           NaN  60,000
# 5      Scholarly Publishing Librarian           NaN  62,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 2                      NaN      USD            NaN            NaN
# 3                   3000.0      USD            NaN            NaN
# 4                   7000.0      USD            NaN            NaN
# 5                      NaN      USD            NaN            NaN
#
#          country           state         city     total_yoe    field_yoe  \
# 0  United States   Massachusetts       Boston     5-7 years    5-7 years
# 2             US       Tennessee  Chattanooga   2 - 4 years  2 - 4 years
# 3            USA       Wisconsin    Milwaukee  8 - 10 years    5-7 years
# 4             US  South Carolina   Greenville  8 - 10 years    5-7 years
# 5            USA   New Hampshire      Hanover  8 - 10 years  2 - 4 years
#
#   highest_education_completed gender   race
# 0             Master's degree  Woman  White
# 2              College degree  Woman  White
# 3              College degree  Woman  White
# 4              College degree  Woman  White
# 5             Master's degree    Man  White

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

country_count=df_salary['country'].value_counts

country_count
# Out:
# <bound method IndexOpsMixin.value_counts of 0                   United States
# 1                  United Kingdom
# 2                              US
# 3                             USA
# 4                              US
#                    ...
# 28067    United States of America
# 28068                        U.S.
# 28069                         USA
# 28070               United States
# 28071                         USA
# Name: country, Length: 28072, dtype: object>

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
country_count=df_salary['country'].value_counts().head(5).index

df_salary['country']=df_salary['country'].replace(country_count,'US')
df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# 2                      NaN      USD            NaN            NaN
# 3                   3000.0      USD            NaN            NaN
# 4                   7000.0      USD            NaN            NaN
#
#           country           state         city     total_yoe    field_yoe  \
# 0              US   Massachusetts       Boston     5-7 years    5-7 years
# 1  United Kingdom             NaN    Cambridge  8 - 10 years    5-7 years
# 2              US       Tennessee  Chattanooga   2 - 4 years  2 - 4 years
# 3              US       Wisconsin    Milwaukee  8 - 10 years    5-7 years
# 4              US  South Carolina   Greenville  8 - 10 years    5-7 years
#
#   highest_education_completed      gender   race
# 0             Master's degree       Woman  White
# 1              College degree  Non-binary  White
# 2              College degree       Woman  White
# 3              College degree       Woman  White
# 4              College degree       Woman  White

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
country_counter= df_salary['country'].value_counts
country_counter
# Out:
# <bound method IndexOpsMixin.value_counts of 0                   United States
# 1                  United Kingdom
# 2                              US
# 3                             USA
# 4                              US
#                    ...
# 28067    United States of America
# 28068                        U.S.
# 28069                         USA
# 28070               United States
# 28071                         USA
# Name: country, Length: 28072, dtype: object>

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary['country'] = df_salary['country'].str.lower().str.strip()

df_salary['country']=df_salary['country'].str.lower().str.strip()
country_replacements = {
    'united states of america': 'us',
    'united states':'us',
    'usa':'us',
    'u.s.':'us'

}

df_salary['country'] = df_salary['country'].replace(country_replacements)


print (df_salary['country'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0                    us
# 1        united kingdom
# 2                    us
# 3                    us
# 4                    us
#               ...
# 28067                us
# 28068                us
# 28069                us
# 28070                us
# 28071                us
# Name: country, Length: 28072, dtype: object>

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_salary['country'].nunique()
df_salary['country'].value_counts()
# Out:
# country
# us                         22947
# canada                      1678
# uk                           692
# united kingdom               633
# australia                    389
#                            ...
# england, gb                    1
# danmark                        1
# u.k. (northern england)        1
# u.k                            1
# burma                          1
# Name: count, Length: 255, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary.head()
df_salary['salary'].agg(['min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
#       3 df_salary.head()
# ----> 4 df_salary['salary'].agg(['min','max','mean'])
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\series.py:4766, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4763     func = dict(kwargs.items())
#    4765 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766 result = op.agg()
#    4767 return result
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:1430, in SeriesApply.agg(self)
#    1429 def agg(self):
# -> 1430     result = super().agg()
#    1431     if result is None:
#    1432         obj = self.obj
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)
#     324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:369, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     363 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     364 args = (
#     365     [self.axis, *self.args]
#     366     if include_axis(op_name, colg)
#     367     else self.args
#     368 )
# --> 369 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     370 results.append(new_res)
#     372 # make sure we find a good name
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\series.py:4766, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4763     func = dict(kwargs.items())
#    4765 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766 result = op.agg()
#    4767 return result
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:1430, in SeriesApply.agg(self)
#    1429 def agg(self):
# -> 1430     result = super().agg()
#    1431     if result is None:
#    1432         obj = self.obj
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File c:\Users\BeastPV\anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '55,00054,60034,00062,00060,00062,00033,00050,000112,00045,00047,50062,000100,00052,00032,00024,00085,00059,00098,00054,00074,00050,00063,00096,00044,50060,00062,00048,000140,00080,00039,000125,000230,000110,00050,00068,00041,00076,00078,00037,000100,00035,00065,000187,500110,00066,625144,600200,850120,00097,50096,00053,00095,00072,00052,000106,000115,000100,50033,20052,00052,00079,000104,00075,00052,00070,00084,00053,00034,00038,00087,000122,00045,00045,00088,00071,00071,00075,00080,000125,00065,00036,00055,00090,000105,00060,00065,00085,00039,520115,00076,000180,00090,00019,30065,00098,16663,5005847,70087,00048,00039,63553,00047,255196,00034,361150,00075,00020,000107,22078,00095,00042,000100,00050,000119,00066,00060,00075,000145,00095,00048,00075,00042,00054,00092,00050,87060,000101,50036,88385,00062,000130,00055,00059,01571,00053,00063,00095,00085,00035,00033,28056,00085,00062,00074,00063,00045,00018,00086,00019,00042,000114,00073,00054,000100,00027,00060,129135,000130,00026,00060,00037,00085,00045,00092,0003565,00035,